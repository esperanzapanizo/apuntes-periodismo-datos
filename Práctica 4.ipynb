# %% [markdown]
# # Análisis de unidades luminosas (farolas)

# %% [raw]
# Primero, instalaré las librerías de pandas.

# %%
# !pip install pandas

# %% [markdown]
# A continuación, importo las librerías.

# %%
import pandas as pd

# %%
url_movilidad = "https://datos.madrid.es/egob/catalogo/300573-1-unidades-luminosas-farolas.csv"

# %%
url_movilidad
# Out:
# 'https://datos.madrid.es/egob/catalogo/300573-1-unidades-luminosas-farolas.csv'

# %%
df = pd.read_csv(url_movilidad)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-8e853d455511> in <module>
# ----> 1 df = pd.read_csv(url_movilidad)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = pd.read_csv('./20220408_DATOS_ABIERTOS_UNIDAD_LUMINOSA_.csv')

# %%
df
# Out:
#                                                tipo_bloqu  \
# 0       LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;3;200...
# 1       LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;10;31...
# 2       GLED001;LED;PLAZA;DE;MAR DEL PLATA;NUMERO;12;1...
# 3       FFLED005;LED;CALLE;DEL;MAR AMARILLO;NUMERO;21;...
# 4       FFLED005;LED;CALLE;DEL;MAR AMARILLO;NUMERO;19;...
# ...                                                   ...
# 233304  LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;4;310...
# 233305  LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;6;310...
# 233306  LBE026;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;9;111...
# 233307  LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;9;111...
# 233308  LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;1;111...
#
#                           C     50;TIPOL  C.1  254;VIA_CLASE  C.2  \
# 0       48120000000;4480670  67020000000  NaN            NaN  NaN
# 1       64160000000;4480740  99560000000  NaN            NaN  NaN
# 2       07500000000;4480679  16380000000  NaN            NaN  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233309 entries, 0 to 233308
# Data columns (total 31 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tipo_bloqu      233309 non-null  object
#  1   C               233309 non-null  object
#  2   50;TIPOL        233309 non-null  int64
#  3   C.1             0 non-null       float64
#  4   254;VIA_CLASE   0 non-null       float64
#  5   C.2             0 non-null       float64
#  6   254;VIA_PAR     0 non-null       float64
#  7   C.3             0 non-null       float64
#  8   254;VIA_NOMBRE  0 non-null       float64
#  9   C.4             0 non-null       float64
#  10  254;CLASE_APP   0 non-null       float64
#  11  C.5             0 non-null       float64
#  12  254;NUMERO      0 non-null       float64
#  13  N               0 non-null       float64
#  14  10              0 non-null       float64
#  15  0;COD_NDP       0 non-null       float64
# ...

# %%
df.head()
# Out:
#                                           tipo_bloqu                    C  \
# 0  LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;3;200...  48120000000;4480670
# 1  LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;10;31...  64160000000;4480740
# 2  GLED001;LED;PLAZA;DE;MAR DEL PLATA;NUMERO;12;1...  07500000000;4480679
# 3  FFLED005;LED;CALLE;DEL;MAR AMARILLO;NUMERO;21;...  53530000000;4480644
# 4  FFLED005;LED;CALLE;DEL;MAR AMARILLO;NUMERO;19;...  16270000000;4480635
#
#       50;TIPOL  C.1  254;VIA_CLASE  C.2  254;VIA_PAR  C.3  254;VIA_NOMBRE  \
# 0  67020000000  NaN            NaN  NaN          NaN  NaN             NaN
# 1  99560000000  NaN            NaN  NaN          NaN  NaN             NaN
# 2  16380000000  NaN            NaN  NaN          NaN  NaN             NaN
# 3  66020000000  NaN            NaN  NaN          NaN  NaN             NaN
# 4   1820000000  NaN            NaN  NaN          NaN  NaN             NaN
#
#    C.4  ...  0;BARRIO  N.3  10.3  0;X_UTM  N.4  19  11;Y_UTM  N.5  19.1  11
# ...

# %% [markdown]
# Hasta ahora, hemos importado la libreria de datos en el phyton, y hemos enseñado las primeras variables (antes veíamos muchas y ahora solo las primeras 5)

# %%
df.columns
# Out:
# Index(['tipo_bloqu', 'C', '50;TIPOL', 'C.1', '254;VIA_CLASE', 'C.2',
#        '254;VIA_PAR', 'C.3', '254;VIA_NOMBRE', 'C.4', '254;CLASE_APP', 'C.5',
#        '254;NUMERO', 'N', '10', '0;COD_NDP', 'N.1', '10.1', '0;DISTRITO',
#        'N.2', '10.2', '0;BARRIO', 'N.3', '10.3', '0;X_UTM', 'N.4', '19',
#        '11;Y_UTM', 'N.5', '19.1', '11'],
#       dtype='object')

# %% [markdown]
# Estos de arriba son los nombres de las columnas extraidos de la tabla.

# %%
df.tail()
# Out:
#                                                tipo_bloqu  \
# 233304  LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;4;310...
# 233305  LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;6;310...
# 233306  LBE026;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;9;111...
# 233307  LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;9;111...
# 233308  LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;1;111...
#
#                           C     50;TIPOL  C.1  254;VIA_CLASE  C.2  \
# 233304  72200000000;4480688   4830000000  NaN            NaN  NaN
# 233305  87790000000;4480710  60620000000  NaN            NaN  NaN
# 233306  35970000000;4480727  38290000000  NaN            NaN  NaN
# 233307  63950000000;4480730   2000000000  NaN            NaN  NaN
# 233308  21550000000;4480658  20960000000  NaN            NaN  NaN
#
#         254;VIA_PAR  C.3  254;VIA_NOMBRE  C.4  ...  0;BARRIO  N.3  10.3  \
# 233304          NaN  NaN             NaN  NaN  ...       NaN  NaN   NaN
# ...

# %% [markdown]
# Esta vez hemos seleccionado las últimas 5 filas de la tabla.

# %%
df.set_index('tipo_bloqu')
# Out:
#                                                                       C  \
# tipo_bloqu
# LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;3;2004...  48120000000;4480670
# LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;10;310...  64160000000;4480740
# GLED001;LED;PLAZA;DE;MAR DEL PLATA;NUMERO;12;11...  07500000000;4480679
# FFLED005;LED;CALLE;DEL;MAR AMARILLO;NUMERO;21;1...  53530000000;4480644
# FFLED005;LED;CALLE;DEL;MAR AMARILLO;NUMERO;19;1...  16270000000;4480635
# ...                                                                 ...
# LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;4;3102...  72200000000;4480688
# LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;6;3102...  87790000000;4480710
# LBE026;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;9;1111...  35970000000;4480727
# LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;9;1111...  63950000000;4480730
# LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;1;1111...  21550000000;4480658
#
#                                                        50;TIPOL  C.1  \
# tipo_bloqu
# ...

# %%
df.set_index('tipo_bloqu')['C']
# Out:
# tipo_bloqu
# LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;3;20040016;16;4;445648       48120000000;4480670
# LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;10;31024246;16;4;445610      64160000000;4480740
# GLED001;LED;PLAZA;DE;MAR DEL PLATA;NUMERO;12;11119324;16;4;445680     07500000000;4480679
# FFLED005;LED;CALLE;DEL;MAR AMARILLO;NUMERO;21;11119327;16;4;445669    53530000000;4480644
# FFLED005;LED;CALLE;DEL;MAR AMARILLO;NUMERO;19;11119326;16;4;445651    16270000000;4480635
#                                                                              ...
# LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;4;31022348;16;4;445636       72200000000;4480688
# LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;6;31022349;16;4;445626       87790000000;4480710
# LBE026;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;9;11119314;16;4;445612       35970000000;4480727
# LBE002;DESCARGA;CALLE;DE LAS;ERAS;NUMERO;9;11119314;16;4;445616       63950000000;4480730
# ...

# %%
df.set_index('tipo_bloqu')['C'].plot(title="unidades luminosas")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-fd18bf9fbcc2> in <module>
# ----> 1 df.set_index('tipo_bloqu')['C'].plot(title="unidades luminosas")
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...
